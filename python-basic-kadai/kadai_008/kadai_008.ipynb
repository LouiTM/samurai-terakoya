# %%
def fizzbuzz(var: int):
  if var%15 == 0:
    print("fizzbuzz")
  elif var%3 == 0:
    print("fizz")
  elif var%5 == 0:
    print("buzz")
  else:
    print(f"{var}")
fizzbuzz(9)
fizzbuzz(10)
fizzbuzz(15)
fizzbuzz(2)
# Out:
# fizz
# buzz
# fizzbuzz
# 2
